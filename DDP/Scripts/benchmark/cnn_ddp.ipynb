# %%
import torch
from torch import nn

# import torchvision
import torchvision
from torchvision import datasets
from torchvision.transforms import ToTensor

# import matplotlib for visualization
import matplotlib.pyplot as plt

# %%
print(f"Pytorch version {torch.__version__}")
print(f"torchvision version {torchvision.__version__}")
# Out:
# Pytorch version 2.7.1+cu126
# torchvision version 0.22.1+cu126

# %%
# setup train dataset
train_data = datasets.FashionMNIST(
    root="/home/chick/Desktop/coding/pytorch_learn/pytorch_computer_vision/data",
    train=True,
    download=True,
    transform=ToTensor(),
    target_transform=None
)

# setup test data
test_data = datasets.FashionMNIST(
    root="/home/chick/Desktop/coding/pytorch_learn/pytorch_computer_vision/data",
    train=False,
    download=True,
    transform=ToTensor()
)


# let's peek into train dataset
# looking into first datapoint
# [color_channels=1, height=28, width=28] # image is grayscale
print(train_data[0][0].shape, train_data[0][1])
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[3], line 2
#       1 # setup train dataset
# ----> 2 train_data = datasets.FashionMNIST(
#       3     root="/home/chick/Desktop/coding/pytorch_learn/pytorch_computer_vision/data",
#       4     train=True,
#       5     download=True,
#       6     transform=ToTensor(),
#       7     target_transform=None
#       8 )
#      10 # setup test data
#      11 test_data = datasets.FashionMNIST(
#      12     root="/home/chick/Desktop/coding/pytorch_learn/pytorch_computer_vision/data",
#      13     train=False,
#      14     download=True,
#      15     transform=ToTensor()
#      16 )
#
# File ~/.local/lib/python3.9/site-packages/torchvision/datasets/mnist.py:100, in MNIST.__init__(self, root, train, transform, target_transform, download)
#      97     return
#      99 if download:
# --> 100     self.download()
# ...
